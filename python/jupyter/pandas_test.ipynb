# %%
import pandas as pd

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
cd
# Out:
# C:\Users\zhouc3

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 5C39-2702
#
#  Directory of C:\Users\zhouc3
#
# 2017/12/27  13:58    <DIR>          .
# 2017/12/27  13:58    <DIR>          ..
# 2017/05/23  11:02    <DIR>          .cisco
# 2017/05/26  11:10             2,084 .csp_ovftool_settings.js
# 2017/08/17  10:12    <DIR>          .InstallAnywhere
# 2017/12/27  13:30    <DIR>          .ipynb_checkpoints
# 2017/12/26  16:38    <DIR>          .ipython
# 2017/12/26  16:40    <DIR>          .jupyter
# 2017/12/27  13:59    <DIR>          .matplotlib
# 2017/05/25  10:24    <DIR>          .nuget
# 2017/11/23  18:24    <DIR>          .oracle_jre_usage
# 2017/11/23  18:24    <DIR>          .p4merge
# 2017/11/23  19:54    <DIR>          .p4qt
# 2017/12/19  11:47    <DIR>          .pylint.d
# 2017/12/19  15:08    <DIR>          .ssh
# 2017/12/19  10:40    <DIR>          .vscode
# 2017/12/21  16:39    <DIR>          Contacts
# 2017/12/25  10:40    <DIR>          Desktop
# ...

# %%
pwd
# Out:
# 'C:\\Users\\zhouc3'

# %%
# !ver
# Out:
# Microsoft Windows [Version 10.0.14393]

# %%
# !systeminfo
# Out:
# Host Name:                 CNENZHOUC3L1C
# OS Name:                   Microsoft Windows 10 Enterprise
# OS Version:                10.0.14393 N/A Build 14393
# OS Manufacturer:           Microsoft Corporation
# OS Configuration:          Member Workstation
# OS Build Type:             Multiprocessor Free
# Registered Owner:          EMC
# Registered Organization:   EMC
# Product ID:                00329-00000-00003-AA951
# Original Install Date:     2017/11/23, 17:32:48
# System Boot Time:          2017/12/25, 10:29:50
# System Manufacturer:       LENOVO
# System Model:              20BWS1D627
# System Type:               x64-based PC
# Processor(s):              1 Processor(s) Installed.
#                            [01]: Intel64 Family 6 Model 61 Stepping 4 GenuineIntel ~2295 Mhz
# BIOS Version:              LENOVO JBET51WW (1.16 ), 2015/7/8
# Windows Directory:         C:\WINDOWS
# System Directory:          C:\WINDOWS\system32
# Boot Device:               \Device\HarddiskVolume1
# ...

# %%
from pandas_datareader import data

# %%
SS600000 = data.DataReader('600000.SS', 'yahoo')

# %%
SS600000
# Out:
#                 Open      High       Low     Close  Adj Close       Volume
# Date
# 2010-01-04   9.03298   9.04953   8.75574   8.76815   5.978391  159964607.0
# 2010-01-05   8.85919   8.92953   8.60264   8.83436   6.023535  278278034.0
# 2010-01-06   8.80953   8.81367   8.63988   8.66057   5.905039  233894449.0
# 2010-01-07   8.63988   8.70609   8.39988   8.46609   5.772437  205990015.0
# 2010-01-08   8.41644   8.60678   8.39988   8.56126   5.837327  158795668.0
# 2010-01-11   8.93781   9.02057   8.51161   8.56126   5.837327  281073839.0
# 2010-01-12   8.53643   8.67712   8.38333   8.60678   5.868364  199017998.0
# 2010-01-13   8.37919   8.42057   8.19299   8.20540   5.594690  353804116.0
# 2010-01-14   8.22196   8.28402   8.12678   8.26333   5.634190  186909441.0
# 2010-01-15   8.28402   8.37919   8.15989   8.29230   5.653942  167196170.0
# 2010-01-18   8.23851   8.39575   8.22196   8.37506   5.710370  169024525.0
# ...

# %%
SS600000.plot()
